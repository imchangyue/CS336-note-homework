# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 在不使用ROPE时，我们把结果计算如上，发现的问题是一句话中的如果token顺序不同，但是最终求出的每一个token对应的attention是一样的，但是按理来说，**token顺序应该会对句子的含义产生影响，从而上下文会对一个attention产生影响**

# %% [markdown]
# **想找一个方法，把位置信息融合进去**
# 这个方法是f(x,i)其中i是位置信息，此时的attention的计算公式如下（即原来的$X \to X'$,其实就是乘以一个位置信息$e^{im\theta}$）
# ![image.png](attachment:image.png)
# 而且计算内积发现，**这里的两个token的位置信息是相对位置**而不是绝对位置（由欧拉公式可以证明得到）
